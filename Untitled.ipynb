# %%
import os

image_path = r"C:\Users\vk740\OneDrive\Desktop\Infosys Training\Classification_Model\aadhar.jpg"
if os.path.exists(image_path):
    print("File exists!")
else:
    print("File does not exist!")
# Out:
# File exists!
